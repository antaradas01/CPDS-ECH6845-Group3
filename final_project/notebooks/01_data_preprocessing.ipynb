# %% [markdown]
# # Data Preprocessing
# Use this notebook to clean raw data files before modeling.
# - Start from raw IPEDS/Scorecard extracts.
# - Produce "institute_most_recent_processed.csv" and "merged_course_level.csv".
# - See "notebooks/03_model_training.ipynb" for the required columns.
